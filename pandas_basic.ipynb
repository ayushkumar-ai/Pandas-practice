# %%
import pandas as pd

# Create DataFrame
data = {
    "name": ["A", "B", "C"],
    "age": [20, 21, 22],
    "marks": [85, 90, 88]
}

df = pd.DataFrame(data)

df.head()
df.describe()

# Filtering
df[df["marks"] > 85]
# Out:
#   name  age  marks
# 1    B   21     90
# 2    C   22     88
